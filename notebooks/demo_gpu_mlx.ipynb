# %% [markdown]
# # Demo GPU computation
# This demonstrates the use of low-level routines with a GPU.

# %% [markdown]
# ### Generate fake data

# %%
from edge_analysis.io import simulated_awgn

duration = 4
fs = 15.36e6
analysis_bandwidth = 10e6

raw_iq = simulated_awgn(duration, fs)

# %% [markdown]
# ### Analysis bandpass filter

# %%
from edge_analysis import channel_analysis
from scipy import signal

sos = channel_analysis.generate_iir_lpf(
    rp_dB=0.1,
    rs_dB=70,
    cutoff_Hz=analysis_bandwidth / 2,
    width_Hz=250e3,
    fs=fs,
).astype('float32')

# %timeit -n1 -r1 signal.sosfilt(sos, raw_iq)
iq = signal.sosfilt(sos, raw_iq)
# Out:
# 1.05 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
import mlx.core as mx

iq_mx = mx.array(iq.copy())
# %timeit -n1 -r1 mx.fft.fft(iq_mx[:2*1024])
# Out:
# 678 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ### Channel power time-series

# %%
import iqwaveform
from edge_analysis import channel_analysis

detector_period = 10e-3

pvt = channel_analysis.power_time_series(
    iq_mx, fs=fs, detector_period=detector_period, detectors=('rms', 'peak')
)

print('cpu')
# %timeit -n1 -r1 channel_analysis.power_time_series(iq, fs=fs, detector_period=detector_period, detectors=('rms', 'peak'))
print('mx')
# %timeit -n1 -r1 channel_analysis.power_time_series(iq_mx, fs=fs, detector_period=detector_period, detectors=('rms', 'peak'))
# Out:
# cpu
# 437 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# mx
# 30.8 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
from iqwaveform import powtodB
from iqwaveform.env import set_caption
from matplotlib import pyplot as plt
import numpy as np

plt.style.use('iqwaveform.ieee_double_column')

for detector, trace in pvt.items():
    plt.plot(
        np.arange(trace.size) * detector_period,
        powtodB(trace),
        rasterized=True,
        label=detector,
    )

plt.legend(ncol=3)
plt.title('power vs time M3 statistics', visible=False)
plt.ylabel('Channel power (dBm/10 MHz)');

# %% [markdown]
# ### Cyclic channel power

# %%
from iqwaveform.power_analysis import iq_to_cyclic_power

cyclic_power_resolution = 1e-3 / 15 / 4

print('numpy:')
# %timeit -n1 -r1 iq_to_cyclic_power(\
    iq, 1/fs,\
    cyclic_period=detector_period,\
    detector_period=cyclic_power_resolution,\
    detectors=list(pvt.keys()),\
    cycle_stats=('min', 'mean', 'max'),\
)

print('mx:')
# %timeit -n1 -r1 iq_to_cyclic_power(\
    iq_mx, 1/fs,\
    cyclic_period=detector_period,\
    detector_period=cyclic_power_resolution,\
    detectors=list(pvt.keys()),\
    cycle_stats=('min', 'mean', 'max'),\
)

powerstats_cyclic = iq_to_cyclic_power(
    iq,
    1 / fs,
    cyclic_period=detector_period,
    detector_period=cyclic_power_resolution,
    detectors=list(pvt.keys()),
    cycle_stats=('min', 'mean', 'max'),
)

powerstats_cyclic = iq_to_cyclic_power(
    iq,
    1 / fs,
    cyclic_period=detector_period,
    detector_period=cyclic_power_resolution,
    detectors=list(pvt.keys()),
    cycle_stats=('min', 'mean', 'max'),
)
# Out:
# numpy:
# 448 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# mx:
# 59.3 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
from matplotlib.ticker import EngFormatter

fig, ax = plt.subplots()

for i, (detector, cyclic_traces) in enumerate(powerstats_cyclic.items()):
    t = np.arange(cyclic_traces['mean'].size) * cyclic_power_resolution

    ax.plot(
        t,
        powtodB(cyclic_traces['mean']),
        label=f'{detector} detector',
        color=f'C{i}',
        lw=1,
    )

    ax.fill_between(
        t,
        powtodB(cyclic_traces['min']),
        powtodB(cyclic_traces['max']),
        color=f'C{i}',
        alpha=0.25,
        lw=0,
        rasterized=True,
    )

ax.xaxis.set_major_formatter(EngFormatter(unit='s'))
ax.legend()
ax.set_xlabel('Cyclic lag')
ax.set_ylabel('Channel power (dBm/10 MHz)')

ax.set_title(
    f'Cyclic channel power evaluated with resolution {cyclic_power_resolution/1e-6:0.1f} us'
);

# %% [markdown]
# ### Persistence Spectrum

# %%
frequency_resolution = 16e3
spectrum_quantiles = [0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99, 0.999, 1]

# %timeit -n1 -r1 channel_analysis.persistence_spectrum(iq, fs=fs, window='flattop', fres=frequency_resolution, quantiles=spectrum_quantiles)
freqs, spectrum = channel_analysis.persistence_spectrum(
    iq_mx,
    fs=fs,
    window='flattop',
    fres=frequency_resolution,
    quantiles=spectrum_quantiles,
)
# Out:
# 1.75 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       2 spectrum_quantiles = [0.1,0.25,0.5,0.75,0.9,0.95,0.99,0.999,1]
#       4 get_ipython().run_line_magic('timeit', "-n1 -r1 channel_analysis.persistence_spectrum(iq, fs=fs, window='flattop', fres=frequency_resolution, quantiles=spectrum_quantiles)")
# ----> 5 freqs, spectrum = channel_analysis.persistence_spectrum(iq_mx, fs=fs, window='flattop', fres=frequency_resolution, quantiles=spectrum_quantiles)
#
# File ~/Documents/src/spectrum-sensor-edge-analysis/src/edge_iq/channel_analysis.py:70, in persistence_spectrum(iq, fs, window, fres, quantiles)
#      68 xp = array_namespace(iq)
#      69 fft_size = int(fs/fres)
# ---> 70 freqs, times, X = iqwaveform.stft(iq, window='flattop', fs=fs, nperseg=fft_size)
#      71 spectrum = xp.quantile(iqwaveform.envtopow(X), quantiles, axis=0)
#      72 return freqs, iqwaveform.powtodB(spectrum.T)
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/spectrum-sensor-edge-analysis/lib/python3.9/site-packages/iqwaveform/fourier.py:181, in stft(x, fs, window, nperseg, noverlap, axis, truncate, norm)
#     179 if noverlap == 0:
#     180     x = to_blocks(x, fft_size, truncate=truncate)
# --> 181     X = xp.fft.fftshift(
#     182         fft(x * broadcast_onto(w / fft_size, x, 1), axis=axis + 1),
#     183         axes=axis + 1,
#     184     )
#     186 else:
#     187     if axis != 0:
#
# AttributeError: module 'mlx.core.fft' has no attribute 'fftshift'

# %%
fig, ax = plt.subplots()

ax.plot(freqs, spectrum)
ax.legend(spectrum_quantiles, title='Quantile')
ax.set_xlabel('Baseband Frequency')
ax.xaxis.set_major_formatter(EngFormatter(unit='Hz'))
ax.set_ylabel(f'Power spectral density (dBm/{frequency_resolution/1e3:0.0f} kHz)');

# %% [markdown]
# ### Amplitude Probability Distribution

# %%
apd_bins = dict(power_low=-40, power_high=15, power_count=161)

# %timeit -n1 -r1 channel_analysis.amplitude_probability_distribution(iq, **apd_bins)
ccdf, bins = channel_analysis.amplitude_probability_distribution(iq, **apd_bins)

fig, ax = plt.subplots()
ax.plot(ccdf, bins)
ax.set_xscale('gamma-qq', k=1, major_ticks=16, db_ordinal=True)
ax.set_ylabel(f'Channel power (dBm/{analysis_bandwidth/1e6:0.0f} MHz)')
ax.set_xlabel('Probability of exceeding ordinate');
# Out:
# 2.67 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
